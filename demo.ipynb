# %%
import matplotlib.pyplot as plt

# %%
language = ["Python", "HTML", "CSS", "JS", "Go", "Java", "Rust"]
percentage = ["20.05%", "30.09%", "40.07%", "37.84%", "84.64%", "35.83%"]
l_dict = dict(zip(language, percentage))
l_dict.items()
# Out:
# dict_items([('Python', '20.05%'), ('HTML', '30.09%'), ('CSS', '40.07%'), ('JS', '37.84%'), ('Go', '84.64%'), ('Java', '35.83%')])

# %%
l_dict = dict(sorted(l_dict.items(), key = lambda x:x[1], reverse = True))
l_dict
# Out:
# {'Go': '84.64%',
#  'CSS': '40.07%',
#  'JS': '37.84%',
#  'Java': '35.83%',
#  'HTML': '30.09%',
#  'Python': '20.05%'}

# %%
# Chart style
fig, ax = plt.subplots(figsize=(6, 2.5))
fig.patch.set_facecolor("#0d1117")  # GitHub dark background
ax.set_facecolor("#0d1117")
# ax.axis("off")

# Colors for the dots and bars 
colors = ["#e34c26", "#3572A5", "#f1e05a", "#563d7c", "#384d54", "#ff9900"]

# Title 
ax.text(0.05, 1.05, "Most Used Languages", fontsize=18, color="#58a6ff", fontweight="bold")

# Rounded border
for spine in ax.spines.values():
    spine.set_visible(False)

offset = 0
for i, (lang, perc) in enumerate(zip(language, percentage)):
    if i%2 == 0:
        text = ax.text(0.15, 0.7 + offset, lang, fontsize=10, color="#58a6ff", fontweight="bold")
        offset -= 0.2
    else: 
        



    


# Draw progress bar style chart
# for i, (lan, perc) in enumerate(zip(lang, perct)):
    # y = len(lan) - i - 1
    # ax.barh(y, perc, color=colors[i % len(colors)], height=0.25, edgecolor='none', zorder=3)
    # ax.scatter(0, y, color=colors[i % len(colors)], s=120, zorder=4)
    # ax.text(0.1, y, f"{lan} {perc:.2f}%", va='center', color="#94e2d5", fontsize=11, fontweight='bold')

# %%
for i in range(0,11):
    if i%2 == 0:
        print(f"{i} is even")
    else:
        print(f"{i} is odd")
# Out:
# 0 is even
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
